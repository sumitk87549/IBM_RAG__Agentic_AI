# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # <a id='toc1_'></a>[Use Mistral and gTTS to Create Your Personal Storyteller](#toc0_)

# %% [markdown]
# Estimated time needed: **30** minutes
#
#
# In this project, you will learn how to use Mistral and gTTS to create your personal storyteller.

# %% [markdown]
# ## __Table of Contents__
#
# <ol>
#     <li><a href="#Introduction">Introduction</a></li>
#     <li><a href="#What-does-this-guided-project-do?">What does this guided project do?</a></li>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li>
#         <a href="#Background">Background</a>
#         <ol>
#             <li><a href="#What-is-large-language-model-(LLM)?">What is large language model (LLM)?</a></li>
#             <li><a href="#What-is-Mistral?">What is Mistral?</a></li>
#             <li><a href="#What-is-gTTS-(Google-Text-to-Speech)?">What is gTTS (Google Text-to-Speech)?</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Installing-required-libraries">Installing required libraries</a></li>
#         </ol>
#     </li>
#     <li><a href="#Connecting-to-local-Ollama">Connecting to local Ollama</a></li>
#     <li>
#         <a href="#Work-with-foundation-models-on-local-Ollama">Work with foundation models on local Ollama</a>
#         <ol>
#             <li><a href="#List-available-models">List available models</a></li>
#             <li><a href="#Defining-model-parameters">Defining model parameters</a></li>
#         </ol>
#     </li>
#     <li><a href="#Generate-a-story-with-Mistral">Generate a story with Mistral</a></li>
#     <li><a href="#Convert-the-story-to-speech">Convert the story to speech</a></li>
#     <li><a href="#Save-the-audio-to-a-file">(Optional) Save the audio to a file</a></li>
#     <li>
#         <a href="#Exercises">Exercises</a>
#         <ol>
#             <li><a href="#Exercise-1:-Generate-another-story">Exercise 1: Generate another story</a></li>
#         </ol>
#     </li>
#     <li><a href="#Authors">Authors</a></li>
#     <li><a href="#Contributors">Contributors</a></li>
# </ol>

# %% [markdown]
# <h2 id="Introduction"><a href="#Table-of-Contents">Introduction</a></h2>
#
# Have you ever wanted to create engaging stories and have them read aloud naturally? By combining the power of AI story generation with text-to-speech technology, we can create an interactive storytelling experience. In this project, we'll use Mistral, a large language model, to generate creative stories based on any topic you provide, and then convert these stories into natural-sounding speech.
#
# <h2 id="What-does-this-guided-project-do"><a href="#Table-of-Contents">What does this guided project do?</a></h2>
#
#
# This project demonstrates how to create an AI storyteller by:
# 1. Using Mistral to generate creative and informative stories based on your chosen topic
# 2. Converting the generated story into speech using gTTS (Google Text-to-Speech)
# 3. Playing the audio directly in your Jupyter notebook
#
# For example, you could input a topic like "the life span of trees," and Mistral will create an engaging narrative about how trees grow, survive through seasons, and can live for hundreds or even thousands of years. This story will then be converted into spoken words, making it perfect for educational content, bedtime stories, or learning about any subject in an auditory format.
#
# <h2 id="Objectives"><a href="#Table-of-Contents">Objectives</a></h2>
#
#
# After completing this lab you will be able to:
# - Use Mistral to generate creative stories from any given topic
# - Convert the generated text to speech using the gTTS library
# - Create an end-to-end pipeline for AI storytelling
# - Play generated audio directly in Jupyter notebooks

# %% [markdown]
# <h2 id="Background"><a href="#Table-of-Contents">Background</a></h2>
#
# <h3 id="What-is-large-language-model-(LLM)?"><a href="#table-of-contents">What is large language model (LLM)?</a></h3>
#
#
# [Large language models](https://www.ibm.com/topics/large-language-models?utm_source=skills_network&utm_content=in_lab_content_link&utm_id=Lab-Use+Mixtral+and+gTTS+to+create+your+personal+storyteller-v1_1738273977) are a category of foundation models trained on immense amounts of data making them capable of understanding and generating natural language and other types of content to perform a wide range of tasks.
#
# <h3 id="What-is-Mistral"><a href="#Table-of-Contents">What is Mistral?</a></h3>
#
# [Mistral](https://mistral.ai/) is an open-source large language model developed by Mistral AI. It's a Mixture of Experts (MoE) model that achieves state-of-the-art performance among open-source models. Key features include:
#
# - **Powerful Performance**: Matches or exceeds the performance of much larger models on most benchmarks
# - **Efficient Architecture**: Uses a Sparse Mixture of Experts architecture, making it more efficient than traditional models
# - **Versatile Applications**: Excellent at tasks like creative writing, analysis, and storytelling
# - **Open Source**: Freely available for research and commercial use
#
# <h3 id="What-is-gTTS"><a href="#Table-of-Contents">What is gTTS (Google Text-to-Speech)?</a></h3>
#
#
# [gTTS (Google Text-to-Speech)](https://gtts.readthedocs.io/) is a Python library and CLI tool that interfaces with Google Translate's text-to-speech API. It offers:
#
# - **Multiple Languages**: Support for a wide variety of languages and accents
# - **Natural Sound**: High-quality, natural-sounding voice synthesis
# - **Easy Integration**: Simple Python interface for converting text to speech
# - **Format Options**: Ability to save audio in MP3 format or stream it directly
# - **Customization**: Control over speech speed and language variants

# %% [markdown]
# <h2 id="Setup"><a href="#Table-of-Contents">Setup</a></h2>
#
# For this lab, we will be using the following libraries:
#
# *   [`ollama`](https://pypi.org/project/ollama/): `ollama` is a python library that provides a simple API to interact with large language models running locally via Ollama. It will be used to communicate with the model hosted at `http://localhost:11434`.
# *   [`gtts`](https://pypi.org/project/gtts/): `gtts` is a library that allows to convert text to speech using Google Text-to-Speech API.

# %% [markdown]
# <h3 id="Installing-required-libraries"><a href="#Table-of-Contents">Installing required libraries</a></h3>
#
#
# The following required libraries are __not__ pre-installed in the Skills Network Labs environment. __You must run the following cell__ to install them. Please wait until it completes.
#
# This step could take **several minutes**, please be patient.
#
# **NOTE**: If you encounter any issues, please restart the kernel and run again.  You can do that by clicking the **Restart the kernel** icon.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/crvBKBOkg9aBzXZiwGEXbw/Restarting-the-Kernel.png" width="100%" alt="Restart kernel">

# %%
# %pip install gTTS==2.5.4 | tail -n 1
# %pip install ollama | tail -n 1

# %% [markdown]
# <h2 id="Connecting-to-local-Ollama"><a href="#Table-of-Contents">Connecting to local Ollama</a></h2>
#
# This section connects to your local Ollama instance.
#
# **Please note:**
#
# We will use the `ollama` Python library to communicate with the local instance running at `http://localhost:11434`. Ensure Ollama is running on your machine and you have pulled the required model (e.g., `ollama pull mistral`).

# %%
import ollama

# By default, the ollama Python client connects to http://localhost:11434
# You can change the host here if your local ollama is running on a different port or machine.
client = ollama.Client(host='http://localhost:11434')

# %% [markdown]
# <h2 id="Work-with-foundation-models-on-local-Ollama"><a href="#Table-of-Contents">Work with foundation models on local Ollama</a></h2>
#
# <h3 id="List-available-models"><a href="#Table-of-Contents">List available models</a></h3>
#
# You can list the models you have currently pulled to your local Ollama instance.

# %%
# List local models available in Ollama
models = client.list()
print("Available local models:")
for model in models.get('models', []):
    print(f"- {model}")
# Out:
# Available local models:
# - model='mistral:7b' modified_at=datetime.datetime(2026, 7, 14, 8, 0, 50, 717370, tzinfo=TzInfo(19800)) digest='6577803aa9a036369e481d648a2baebb381ebc6e897f2bb9a766a2aa7bfbc1cf' size=4372824384 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='7.2B', quantization_level='Q4_K_M')
# - model='qwen3-vl:8b' modified_at=datetime.datetime(2026, 7, 12, 18, 21, 55, 992703, tzinfo=TzInfo(19800)) digest='901cae73216286ea8c5aba8b46d307ff7188f737285ec500c795a12f05225d28' size=6140415879 details=ModelDetails(parent_model='', format='gguf', family='qwen3vl', families=['qwen3vl'], parameter_size='8.8B', quantization_level='Q4_K_M')
# - model='granite3.2-vision:2b' modified_at=datetime.datetime(2026, 7, 12, 18, 21, 45, 941672, tzinfo=TzInfo(19800)) digest='3be41a661804ad72cd08269816c5a145f1df6479ad07e2b3a7e29dba575d2669' size=2437852465 details=ModelDetails(parent_model='/Users/administrator/.ollama/models/blobs/sha256-1aefcd9a8a15091b670951963b5f8a7e6653bb1350345e9621e179685ac9bc5f', format='gguf', family='granite', families=['granite', 'clip'], parameter_size='2.5B', quantization_level='Q4_K_M')
# - model='minicpm-v4.6:1b' modified_at=datetime.datetime(2026, 7, 12, 18, 14, 57, 310067, tzinfo=TzInfo(19800)) digest='e95583acac773b45d95469c069db44808c87295f924183f4c942d52616b2d132' size=1637848812 details=ModelDetails(parent_model='', format='gguf', family='qwen35', families=['qwen35'], parameter_size='752.16M', quantization_level='Q4_K_M')
# - model='qwen3.5:9b' modified_at=datetime.datetime(2026, 7, 12, 18, 12, 59, 677417, tzinfo=TzInfo(19800)) digest='6488c96fa5faab64bb65cbd30d4289e20e6130ef535a93ef9a49f42eda893ea7' size=6594474711 details=ModelDetails(parent_model='', format='gguf', family='qwen35', families=['qwen35'], parameter_size='9.7B', quantization_level='Q4_K_M')
# - model='starcoder2:15b' modified_at=datetime.datetime(2026, 7, 3, 9, 21, 54, 563363, tzinfo=TzInfo(19800)) digest='21ae152d49e026b721a52cda94b32f95b3c9719d5eb71ea670e4fa60efde276b' size=9065413313 details=ModelDetails(parent_model='', format='gguf', family='starcoder2', families=['starcoder2'], parameter_size='16B', quantization_level='Q4_0')
# - model='opencoder:8b' modified_at=datetime.datetime(2026, 7, 3, 9, 16, 42, 507871, tzinfo=TzInfo(19800)) digest='cd882db52297841eb2721a191b598b7671cef506fc8ef123ff1ce04d6863d49f' size=4736066175 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='7.8B', quantization_level='Q4_K_M')
# - model='qwen2.5-coder:7b' modified_at=datetime.datetime(2026, 7, 3, 9, 11, 11, 14779, tzinfo=TzInfo(19800)) digest='dae161e27b0e90dd1856c8bb3209201fd6736d8eb66298e75ed87571486f4364' size=4683087561 details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='7.6B', quantization_level='Q4_K_M')
# - model='command-r7b:7b' modified_at=datetime.datetime(2026, 7, 3, 9, 7, 17, 245125, tzinfo=TzInfo(19800)) digest='ff4e9696ef9f19b62e3f7d7261c95dcc9bb15a7c0398493366d851119fe2e1ef' size=5057031198 details=ModelDetails(parent_model='', format='gguf', family='cohere2', families=['cohere2'], parameter_size='8.0B', quantization_level='Q4_K_M')
# - model='granite-code:8b' modified_at=datetime.datetime(2026, 7, 3, 9, 3, 19, 722832, tzinfo=TzInfo(19800)) digest='36c3c3b9683b411ee20ba5c6c6858df83a1d7bf3b65f9fd76a073791e98a18dd' size=4590918937 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='8.1B', quantization_level='Q4_0')
# - model='codegeex4:9b' modified_at=datetime.datetime(2026, 7, 3, 8, 29, 57, 703545, tzinfo=TzInfo(19800)) digest='867b8e81d03898ac2289d809edb718d67a6d706d6a644bb1a922ee1607c7e5ed' size=5455323291 details=ModelDetails(parent_model='', format='gguf', family='chatglm', families=['chatglm'], parameter_size='9.4B', quantization_level='Q4_0')
# - model='codellama:13b' modified_at=datetime.datetime(2026, 7, 3, 8, 25, 9, 676884, tzinfo=TzInfo(19800)) digest='9f438cb9cd581fc025612d27f7c1a6669ff83a8bb0ed86c94fcf4c5440555697' size=7365960935 details=ModelDetails(parent_model='', format='gguf', family='llama', families=None, parameter_size='13B', quantization_level='Q4_0')
# - model='codegemma:7b' modified_at=datetime.datetime(2026, 7, 3, 8, 20, 45, 123227, tzinfo=TzInfo(19800)) digest='0c96700aaada572ce9bb6999d1fda9b53e9e6cef5d74fda1e066a1ba811b93f3' size=5011852809 details=ModelDetails(parent_model='', format='gguf', family='gemma', families=['gemma'], parameter_size='9B', quantization_level='Q4_0')
# - model='glm4:9b' modified_at=datetime.datetime(2026, 6, 24, 15, 30, 7, 156221, tzinfo=TzInfo(19800)) digest='5b699761eca535dc55047ad9d2dbf54e3b8697709419ef78a70503ed4bfbcf44' size=5455326235 details=ModelDetails(parent_model='', format='gguf', family='chatglm', families=['chatglm'], parameter_size='9.4B', quantization_level='Q4_0')
# - model='mistrallite:7b' modified_at=datetime.datetime(2026, 6, 23, 16, 12, 48, 629961, tzinfo=TzInfo(19800)) digest='5393d4f5f2623b1224406328f504cfdd211e05c252c1c9b7e12dac0b4da1cdcc' size=4108933972 details=ModelDetails(parent_model='', format='gguf', family='llama', families=None, parameter_size='7B', quantization_level='Q4_0')
# - model='translategemma:4b' modified_at=datetime.datetime(2026, 6, 23, 16, 12, 22, 756514, tzinfo=TzInfo(19800)) digest='c49d986b0764f5881c476eb21435bb62b7abc62347aab3d4a6071e811be510a1' size=3298875707 details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='4.3B', quantization_level='Q4_K_M')
# - model='lfm2.5:8b' modified_at=datetime.datetime(2026, 6, 17, 18, 47, 50, 815791, tzinfo=TzInfo(19800)) digest='9cf756159fc2f3b9128c6a3f544ec90c5e9b8afdbb4179a57b8aea9de589cfb2' size=5156075525 details=ModelDetails(parent_model='', format='gguf', family='lfm2moe', families=['lfm2moe'], parameter_size='8.5B', quantization_level='Q4_K_M')
# - model='gemma4:e2b' modified_at=datetime.datetime(2026, 6, 17, 18, 23, 53, 732878, tzinfo=TzInfo(19800)) digest='7fbdbf8f5e45a75bb122155ed546e765b4d9c53a1285f62fd9f506baa1c5a47e' size=7162405886 details=ModelDetails(parent_model='', format='gguf', family='gemma4', families=['gemma4'], parameter_size='5.1B', quantization_level='Q4_K_M')
# - model='llama3.1:8b' modified_at=datetime.datetime(2026, 5, 31, 21, 20, 52, 920606, tzinfo=TzInfo(19800)) digest='46e0c10c039e019119339687c3c1757cc81b9da49709a3b3924863ba87ca666e' size=4920753328 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='8.0B', quantization_level='Q4_K_M')
# - model='rnj-1:8b' modified_at=datetime.datetime(2026, 5, 31, 21, 20, 26, 672748, tzinfo=TzInfo(19800)) digest='d20e29ab8d0f11423b1e8da33764c8bdafc1d0abbb9971f68edd0f6d4176435f' size=5114440677 details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='8.3B', quantization_level='Q4_K_M')
# - model='nemotron-3-nano:4b' modified_at=datetime.datetime(2026, 5, 31, 21, 3, 33, 627629, tzinfo=TzInfo(19800)) digest='6cc467f054393a55e98a74098abde0c762ffb6d1d8cd64becf30458f38886197' size=2837597147 details=ModelDetails(parent_model='', format='gguf', family='nemotron_h', families=['nemotron_h'], parameter_size='4.0B', quantization_level='Q4_K_M')
# - model='cogito:8b' modified_at=datetime.datetime(2026, 5, 28, 5, 29, 35, 375766, tzinfo=TzInfo(19800)) digest='75b508ddece134205c621b91237310024ca983027fb7f724c2032d106419bd1b' size=4920747948 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='8.0B', quantization_level='Q4_K_M')
# - model='hermes3:8b' modified_at=datetime.datetime(2026, 5, 28, 5, 26, 55, 421703, tzinfo=TzInfo(19800)) digest='4f6b83f30b62bc3d0cf9be09266db222805ee815c8fd7d8b38f863f655be78b7' size=4661227243 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='8.0B', quantization_level='Q4_0')
# - model='wizardlm2:7b' modified_at=datetime.datetime(2026, 5, 28, 5, 24, 21, 310021, tzinfo=TzInfo(19800)) digest='c9b1aff820f245a43b1719b296ce7131746073691cbb56f7a8d88a4713a3df79' size=4108928625 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='7B', quantization_level='Q4_0')
# - model='qwen3.5:4b' modified_at=datetime.datetime(2026, 5, 28, 5, 20, 7, 258991, tzinfo=TzInfo(19800)) digest='2a654d98e6fba55d452b7043684e9b57a947e393bbffa62485a7aac05ee4eefd' size=3389983735 details=ModelDetails(parent_model='', format='gguf', family='qwen35', families=['qwen35'], parameter_size='4.7B', quantization_level='Q4_K_M')
# - model='granite3-moe:3b' modified_at=datetime.datetime(2026, 5, 28, 5, 19, 31, 85610, tzinfo=TzInfo(19800)) digest='157f538ae66e0663cee4fb30ef11e3ccf1ae3c1bf6da2698dbac1df3a25698c7' size=2059368194 details=ModelDetails(parent_model='', format='gguf', family='granitemoe', families=['granitemoe'], parameter_size='3.4B', quantization_level='Q4_K_M')
# - model='phi4-mini:3.8b' modified_at=datetime.datetime(2026, 5, 28, 5, 10, 26, 137580, tzinfo=TzInfo(19800)) digest='78fad5d182a7c33065e153a5f8ba210754207ba9d91973f57dffa7f487363753' size=2491876774 details=ModelDetails(parent_model='', format='gguf', family='phi3', families=['phi3'], parameter_size='3.8B', quantization_level='Q4_K_M')
# - model='granite4.1:8b' modified_at=datetime.datetime(2026, 5, 28, 5, 8, 47, 132247, tzinfo=TzInfo(19800)) digest='444af1c4b2fedd6b54041aca558e7300b0b3d5c0468c44619126240323ba2852' size=5347933017 details=ModelDetails(parent_model='/Users/runner/.ollama/models/blobs/sha256-ed902ac9eb6adce5a90c6a08c8ea201b50e23fdc5976d1cd0362006afac5309e', format='gguf', family='granite', families=['granite'], parameter_size='8.8B', quantization_level='Q4_K_M')
# - model='gemma3n:e2b' modified_at=datetime.datetime(2026, 5, 27, 21, 11, 44, 525696, tzinfo=TzInfo(19800)) digest='719372f8c7deee188821a4dcbaf75efa13a342d7e88a79d4fc2412b24947f6fd' size=5621616562 details=ModelDetails(parent_model='', format='gguf', family='gemma3n', families=['gemma3n'], parameter_size='4.5B', quantization_level='Q4_K_M')
# - model='deepseek-r1:7b' modified_at=datetime.datetime(2026, 5, 27, 21, 9, 24, 628812, tzinfo=TzInfo(19800)) digest='755ced02ce7befdb13b7ca74e1e4d08cddba4986afdb63a480f2c93d3140383f' size=4683075440 details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='7.6B', quantization_level='Q4_K_M')
# - model='llama3.2:3b' modified_at=datetime.datetime(2026, 5, 27, 21, 8, 10, 747726, tzinfo=TzInfo(19800)) digest='a80c4f17acd55265feec403c7aef86be0c25983ab279d83f3bcd3abbcb5b8b72' size=2019393189 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='3.2B', quantization_level='Q4_K_M')
# - model='smollm2:1.7b' modified_at=datetime.datetime(2026, 5, 27, 21, 6, 14, 250172, tzinfo=TzInfo(19800)) digest='cef4a1e09247f018ca0c482ad4c2ce1474aba5e87f245dacf97f07948d05d8b4' size=1820428533 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='1.7B', quantization_level='Q8_0')
# - model='granite4.1:3b' modified_at=datetime.datetime(2026, 5, 27, 20, 35, 3, 832884, tzinfo=TzInfo(19800)) digest='6fd349357287c7ffc9e38189a93b48ea175d24fc566b38f09cfc564fb7f303eb' size=2099520281 details=ModelDetails(parent_model='/Users/runner/.ollama/models/blobs/sha256-662b0626cd58f443baea23559b469df6576a81d349649c59413b36a9fb32eb29', format='gguf', family='granite', families=['granite'], parameter_size='3.4B', quantization_level='Q4_K_M')
# - model='nomic-embed-text-v2-moe:latest' modified_at=datetime.datetime(2026, 5, 14, 18, 54, 2, 24768, tzinfo=TzInfo(19800)) digest='ff9c2f10ef5e3722623a1b396e1e04efc27a93112c83e9b7b7b9ca1d05620965' size=957680763 details=ModelDetails(parent_model='/Users/nicole/.ollama/models/blobs/sha256-a5db3381f2e514d3490a3a31fe70eb1a65e95016c85c6c2c23223b810806594f', format='gguf', family='nomic-bert-moe', families=['nomic-bert-moe'], parameter_size='475.29M', quantization_level='F16')
# - model='nomic-embed-text:v1.5' modified_at=datetime.datetime(2026, 5, 14, 18, 53, 9, 705491, tzinfo=TzInfo(19800)) digest='0a109f422b47e3a30ba2b10eca18548e944e8a23073ee3f3e947efcf3c45e59f' size=274302450 details=ModelDetails(parent_model='', format='gguf', family='nomic-bert', families=['nomic-bert'], parameter_size='137M', quantization_level='F16')
# - model='embeddinggemma:300m' modified_at=datetime.datetime(2026, 5, 14, 18, 46, 34, 939507, tzinfo=TzInfo(19800)) digest='85462619ee721b466c5927d109d4cb765861907d5417b9109caebc4e614679f1' size=621875917 details=ModelDetails(parent_model='embeddinggemma:300m-bf16', format='gguf', family='gemma3', families=['gemma3'], parameter_size='307.58M', quantization_level='BF16')
# - model='gemma3:4b' modified_at=datetime.datetime(2026, 5, 14, 18, 18, 45, 826473, tzinfo=TzInfo(19800)) digest='a2af6cc3eb7fa8be8504abaf9b04e88f17a119ec3f04a3addf55f92841195f5a' size=3338801804 details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='4.3B', quantization_level='Q4_K_M')

# %%
# Specify the model_id of the model we will use for the chat.
# Make sure you have pulled this model using `ollama pull mistral`
model_id = 'mistral:7b'

# %% [markdown]
# <h3 id="Defining-model-parameters"><a href="#Table-of-Contents">Defining model parameters</a></h3>
#
# With Ollama, you can pass parameters such as `temperature` directly when making a generation request. For this tutorial, we will define them alongside our model generation call later.

# %%
# In Ollama, we don't need a separate ModelInference object. 
# We can define generation parameters as a dictionary to be passed during generation.
options = {
    "temperature": 0.7,  # Low temperature for more deterministic output
    "num_predict": 1000  # Equivalent to MAX_NEW_TOKENS
}

# %% [markdown]
# <h2 id="Generate-a-story-with-Mistral"><a href="#Table-of-Contents">Generate a story with Mistral</a></h2>
#
# Now we'll create a story using Mistral. We'll first define a function that takes a topic as input and returns a generated story. The function will use a carefully crafted prompt to ensure the story is engaging, educational, and appropriate for beginners.
#
# Let's test our storytelling capabilities by generating a story about a simple topic and converting it to speech.

# %%
# Function to generate an educational story using the local Mistral model
def generate_story(topic):
    # Construct a detailed prompt that guides the model to:
    # - Write for beginners
    # - Use simple language
    # - Include interesting facts
    # - Keep a specific length
    # - End with a summary
    prompt = f"""Write an engaging and educational story about {topic}. 
            Use simple and clear language to explain basic concepts. 
            Include interesting facts and keep it friendly and encouraging. 
            The story should be around 200-300 words and end with a brief summary of what we learned. 
            Make it perfect for someone just starting to learn about this topic."""
    
    # Generate text using the local Ollama client with our carefully crafted prompt
    response = client.generate(model=model_id, prompt=prompt, options=options)
    return response['response']

# Example usage of the generate_story function
# Here we use butterflies as a topic since it's an engaging and 
# educational subject that demonstrates the function well
topic = "Polar-Bears"
story = generate_story(topic)
print("Generated Story:\n", story)
# Out:
# Generated Story:
#   Title: The Wonderful World of Sex: A Friendly Guide for Beginners
#
# Once upon a time, in the beautiful land of Life Lessons, there was a curious young creature named Timmy. Timmy had many questions about growing up and one question that puzzled him the most was, "What is sex?"
#
# One sunny day, Timmy met Olive, an wise old tree who had seen countless seasons. Timmy approached Olive with his question.
#
# "Olive," Timmy asked, "can you tell me about this thing called sex?"
#
# Olive nodded thoughtfully and said, "Of course, Timmy. Sex is a natural and beautiful part of life between two consenting adults. It's how babies are made, but it's also an expression of love and intimacy."
#
# "But how does it work?" Timmy inquired, blushing slightly.
#
# Olive explained, "Sex involves physical closeness between two people. There are many ways to have sex, but one common way is through intercourse, where a man's penis enters a woman's vagina."
#
# "But what about safety?" Timmy asked, concerned.
#
# "That's an important question," Olive replied. "Sex can also lead to pregnancies and sexually transmitted infections (STIs). To prevent unwanted pregnancies, people often use contraception like condoms. To protect against STIs, it's essential to practice safe sex by using protection and getting regular check-ups."
#
# Timmy left Olive feeling more informed and less anxious about his question. He realized that understanding sex was a natural part of growing up and that asking questions was a brave step towards knowledge.
#
# Lesson Learned: Sex is a normal and beautiful aspect of life, often associated with love and intimacy. It's essential to understand the importance of consent, safety, and protection. Always remember that it's okay to ask questions and seek information about sex, as understanding this topic helps us make responsible choices for our health and well-being.

# %% [markdown]
# <h2 id="Convert-the-story-to-speech"><a href="#Table-of-Contents">Convert the story to speech</a></h2>
#
#
# Now that we have generated our story, let's convert it to speech using the gTTS (Google Text-to-Speech) library.
# We'll create an audio file in memory and play it directly in the notebook using an audio player widget.
#
# This step may take a while to complete, please be patient.
#
# **NOTE**: If you encounter any issues, please run the cell again.

# %%
from gtts import gTTS
from IPython.display import Audio
import io

# Initialize text-to-speech with the generated story
tts = gTTS(story)

# Save the audio to a bytes buffer in memory
audio_bytes = io.BytesIO()
tts.write_to_fp(audio_bytes)
audio_bytes.seek(0)

# Create and display an audio player widget in the notebook
Audio(audio_bytes.read(), autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <h2 id="Save-the-audio-to-a-file"><a href="#Table-of-Contents">(Optional) Save the audio to a file</a></h2>
#
#
# ```python
# # Save as MP3 file
# tts.save("generated_story.mp3")
# ```

# %% [markdown]
# <h2 id="Exercises"><a href="#Table-of-Contents">Exercises</a></h2>
#
# <h3 id="Exercise-1:-Generate-another-story"><a href="#Table-of-Contents">Exercise 1: Generate another story</a></h3>
#
#
# Please generate another story with the following topic.
#
# topic = "the life cycle of a human"

# %%
# TODO
topic = "the life cycle of human"

prompt = f"Generate a clear, true, factual and engaging long speech (100-300 words...) about: \n{topic}"
options2 = {"temperature":10, "num_predict":300}

response = client.generate(model= "granite3-moe:3b" , prompt=prompt, options = options2)
print(response.response)
# Out:
# The life cycle of humans is a captivating journey that begins at conception and continues through birth, childhood, adolescence, adulthood, old age, and ultimately, death. Conception marks the beginning of this lifecycle, where a sperm fertilizes an egg, forming a unique human being. This fertilized egg then undergoes rapid cell division to become a embryo, which gradually transforms into a fetus as it develops in the womb. The birth process marks the end of the gestation period and the beginning of life outside the womb.
#
# Childhood is a formative phase during which individuals learn and grow. They are introduced to their surroundings, interact with others, and develop their physical, intellectual, and social skills. Adolescence follows childhood and is marked by significant physiological changes, such as the onset of puberty. This period is also characterized by a strong focus on self-discovery, exploration of identity, and preparation for adulthood.
#
# Adulthood is a stage of personal growth and maturity. Individuals during this phase are often in pursuit of careers, relationships, and personal goals. They may also face various life challenges, such as career changes, health issues, or financial difficulties. Despite these challenges, adulthood is often associated with a sense of accomplish

# %% [markdown]
# <details>
#     <summary>Click here for Solution
#     </summary>
#
# ```python
# topic = "the life cycle of a human"
# story = generate_story(topic)
# print("Generated Story:\n", story)
#
# # Initialize text-to-speech with the generated story
# tts = gTTS(story)
#
# audio_bytes = io.BytesIO()
# tts.write_to_fp(audio_bytes)
# audio_bytes.seek(0)
#
# # Create and display an audio player widget in the notebook
# Audio(audio_bytes.read(), autoplay=True)
# ```
# </details>

# %% [markdown]
# <h2 id="Authors"><a href="#Table-of-Contents">Authors</a></h2>
#
#
# [Ricky Shi](https://author.skills.network/instructors/ricky_shi)
#
# <h2 id="Contributors"><a href="#Table-of-Contents">Contributors</a></h2>
#
# [Hailey Quach](https://www.haileyq.com/)
#
# [Joseph Santarcangelo](https://author.skills.network/instructors/joseph_santarcangelo)
#
# ```{|Date (YYYY-MM-DD)|Version|Changed By|Change Description||-|-|-|-||2025-01-30|1.0|Ricky Shi|Create project|}
# ```

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
